# %%
import requests
from pprint import pprint
from sqlalchemy import create_engine
import pyodbc

# %%
# Create database engine
user = 'team_5_the_departed'
password = 'Spe@kFr1endAndEnter'
host = 'thedeparted.database.windows.net'
databasename = 'the_departed'
driver = 'ODBC+Driver+17+for+SQL+Server'
port = '1433'
engine = create_engine('mssql+pyodbc://{}:{}@{}:{}/{}?driver={}'.format(user, password, host, port, databasename, driver), echo=None)

# %%
cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER='+host+';DATABASE='+databasename+';UID='+user+';PWD='+ password)
cursor = cnxn.cursor()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-1c6a99f4407a> in <module>
# ----> 1 cursor.fetch1()
#
# AttributeError: 'pyodbc.Cursor' object has no attribute 'fetch1'

# %%
from sqlalchemy.engine import URL
connection_string = "DRIVER={ODBC+Driver+17+for+SQL+Server};SERVER=tcp:thedeparted.database.windows.net;DATABASE=the_departed;UID=team_5_the_departed;PWD=Spe@kFr1endAndEnter"
connection_url = URL.create("mssql+pyodbc", query={"odbc_connect": connection_string})
engine=create_engine(connection_url)

# %%
def get_weather(latitude, longitude):
    """Function to return a current weather response from openweather for a given set of co-ordinates"""
    weather_key = "7ac118753938be7d1540e9f996c5aab4"
    weather_by_coordinates = 'http://api.openweathermap.org/data/2.5/weather'
    r = requests.get(weather_by_coordinates,params={"APPID":weather_key, "lat":latitude, "lon":longitude })
    return r.json()

# %%
def store_weather(engine):
    """
    Function to store weather dat in our database.
    Co-ordinates are hard-coded as the same co-ordinates as our historic weather data in the city centre
    Modified from weather scraper in previous project ()
    """
    position_lat = '53.349805'
    position_long = '-6.26031'
    # This calls our function to make the api call
    weather_json = get_weather(position_lat, position_long)
    
    weather_id=weather_json['weather'][0]['id']
    main=weather_json['weather'][0]['main']
    description=weather_json['weather'][0]['description']
    icon=weather_json['weather'][0]['icon']
    icon_url='http://openweathermap.org/img/wn/{}@2x.png'.format(icon)
    
    base=weather_json['base']
    temp=weather_json['main']['temp']
    feels_like=weather_json['main']['feels_like']
    temp_min=weather_json['main']['temp_min']
    temp_max=weather_json['main']['temp_max']
    pressure=weather_json['main']['pressure']
    humidity=weather_json['main']['humidity']
    visibility=weather_json['visibility']
    
    wind_speed=weather_json['wind']['speed']
    wind_degree=weather_json['wind']['deg']
    
    clouds_all=weather_json['clouds']['all']
    
    datetime=weather_json['dt']
    sys_type=weather_json['sys']['type']
    sys_country=weather_json['sys']['country']
    sys_id=weather_json['sys']['id']
    sys_sunrise=weather_json['sys']['sunrise']
    sys_sunset=weather_json['sys']['sunset']
    
    timezone=weather_json['timezone']
    id_var=weather_json['id']
    name=weather_json['name']
    cod=weather_json['cod']
    
    # Write an sql command to insert all this data into the current_weather table
    weather_insert='''INSERT INTO current_weather
    
                                (    position_long
                                    ,position_lat
                                    ,weather_id
                                    ,main
                                    ,description
                                    ,icon
                                    ,icon_url
                                    ,base
                                    ,temp
                                    ,feels_like
                                    ,temp_min
                                    ,temp_max
                                    ,pressure
                                    ,humidity
                                    ,visibility
                                    ,wind_speed
                                    ,wind_degree
                                    ,clouds_all
                                    ,datetime
                                    ,sys_type
                                    ,sys_id
                                    ,sys_country
                                    ,sys_sunrise
                                    ,sys_sunset
                                    ,timezone
                                    ,id
                                    ,name
                                    ,cod)
                                  
                            VALUES
                                (%s
                                  ,%s
                                  ,%s
                                  
                                  ,%s
                                  ,%s
                                  ,%s
                                  ,%s
                                  ,%s
                                  
                                  ,%s
                                  ,%s
                                  ,%s
                                  ,%s
                                  ,%s
                                  ,%s
                                  ,%s
                                  ,%s
                                  
                                  ,%s
                                  ,%s
                                  
                                  ,%s
                                  
                                  ,%s
                                  ,%s
                                  ,%s
                                  ,%s
                                  
                                  ,%s
                                  ,%s
                                  
                                  ,%s
                                  ,%s 
                                  ,%s
                                  ,%s
                                  ,%s)
                                    '''
    weather_values=(position_long
                    ,position_lat
                    ,weather_id
                    ,main
                    ,description
                    ,icon
                    ,icon_url
                    ,base
                    ,temp
                    ,feels_like
                    ,temp_min
                    ,temp_max
                    ,pressure
                    ,humidity
                    ,visibility
                    ,wind_speed
                    ,wind_degree
                    ,clouds_all
                    ,datetime
                    ,sys_type
                    ,sys_id
                    ,sys_country
                    ,sys_sunrise
                    ,sys_sunset
                    ,timezone
                    ,id_var
                    ,name
                    ,cod)
    engine.execute(weather_insert,weather_values)

# %%
db_schema = {
    'current_weather':{
        'entry_id': 'INTEGER'
        ,'dt': 'DATETIME'
        ,'weather_id':'INTEGER'
        ,'weather_main': 'VARCHAR(256)'
        ,'coord_lon': 'REAL'
        ,'coord_lat': 'REAL'
        ,'main':'VARCHAR(256)'
        ,'weather_description':'VARCHAR(500)'
        ,'weather_icon':'VARCHAR(20)'
        ,'base':'varchar(256)'
        ,'main_temp':'REAL'
        ,'main_feels_like':'REAL'
        ,'main_temp_min':'REAL'
        ,'main_temp_max':'REAL'
        ,'main_pressure':'INT'
        ,'main_humidity':'INT'
        ,'visibility':'INT'
        ,'wind_speed':'REAL'
        ,'wind_deg':'INT'
        ,'clouds_all':'INT'
        ,'sys_type':'INT'
        ,'sys_id':'INT'
        ,'sys_country':'VARCHAR(10)'
        ,'sys_sunrise':'BIGINT'
        ,'sys_sunset':'BIGINT'
        ,'timezone':'INT'
        ,'id':'BIGINT'
        ,'name':'VARCHAR(256)'
        ,'cod':'INT'
        }
}

# %%
def create_db_tables(engine, connection):
    """Function to create tables in our database if they do not already exist"""
    for table, columns in db_schema.items():
        column_count = 0
        #sql = """CREATE TABLE IF NOT EXISTS {} (\n""".format(table)
        sql = """if not exists (select * from sysobjects where name='current_weather' and xtype='U')
        CREATE TABLE current_weather (\n"""
        
        insert_row = ''
        
        for column_heading, data_type in columns.items():
            if column_count > 0:
                insert_row += ",\n\t {} {}".format(column_heading, data_type)
            else:
                # Create an auto incremented id column as the very first column.
                insert_row += "\t{} {} NOT NULL IDENTITY PRIMARY KEY".format(column_heading, data_type)
                column_count += 1
        sql += "{})".format(insert_row)
        #conn = engine.connect()
        print(sql)
        engine.execute(sql)
        #engine.fetchone()
        connection.commit
       # engine.execute(sql)

# %%
create_db_tables(cursor, cnxn)
# Out:
# if not exists (select * from sysobjects where name='current_weather' and xtype='U')
#         CREATE TABLE current_weather (
# 	entry_id INTEGER NOT NULL IDENTITY PRIMARY KEY,
# 	 dt DATETIME,
# 	 weather_id INTEGER,
# 	 weather_main VARCHAR(256),
# 	 coord_lon REAL,
# 	 coord_lat REAL,
# 	 main VARCHAR(256),
# 	 weather_description VARCHAR(500),
# 	 weather_icon VARCHAR(20),
# 	 base varchar(256),
# 	 main_temp REAL,
# 	 main_feels_like REAL,
# 	 main_temp_min REAL,
# 	 main_temp_max REAL,
# 	 main_pressure INT,
# 	 main_humidity INT,
# 	 visibility INT,
# 	 wind_speed REAL,
# 	 wind_deg INT,
# 	 clouds_all INT,
# 	 sys_type INT,
# 	 sys_id INT,
# 	 sys_country VARCHAR(10),
# 	 sys_sunrise BIGINT,
# 	 sys_sunset BIGINT,
# 	 timezone INT,
# 	 id BIGINT,
# 	 name VARCHAR(256),
# 	 cod INT)

# %%
store_weather(engine)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# ~\.conda\envs\summer\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1769                 if not evt_handled:
# -> 1770                     self.dialect.do_execute(
#    1771                         cursor, statement, parameters, context
#
# ~\.conda\envs\summer\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     716     def do_execute(self, cursor, statement, parameters, context=None):
# --> 717         cursor.execute(statement, parameters)
#     718
#
# ProgrammingError: ('The SQL contains 0 parameter markers, but 28 parameters were supplied', 'HY000')
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-28-dc35db6125ee> in <module>
# ----> 1 store_weather(engine)
#
# <ipython-input-14-013c1cd60ca9> in store_weather(engine)
#     141                     ,name
#     142                     ,cod)
# --> 143     engine.execute(weather_insert,weather_values)
#
# <string> in execute(self, statement, *multiparams, **params)
#
# ~\.conda\envs\summer\lib\site-packages\sqlalchemy\util\deprecations.py in warned(fn, *args, **kwargs)
#     388         if not skip_warning:
#     389             _warn_with_version(message, version, wtype, stacklevel=3)
# --> 390         return fn(*args, **kwargs)
#     391
#     392     doc = func.__doc__ is not None and func.__doc__ or ""
#
# ~\.conda\envs\summer\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    3105         """
#    3106         connection = self.connect(close_with_result=True)
# -> 3107         return connection.execute(statement, *multiparams, **params)
#    3108
#    3109     @util.deprecated_20(
#
# ~\.conda\envs\summer\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    1245             )
#    1246
# -> 1247             return self._exec_driver_sql(
#    1248                 statement,
#    1249                 multiparams,
#
# ~\.conda\envs\summer\lib\site-packages\sqlalchemy\engine\base.py in _exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1544
#    1545         dialect = self.dialect
# -> 1546         ret = self._execute_context(
#    1547             dialect,
#    1548             dialect.execution_ctx_cls._init_statement,
#
# ~\.conda\envs\summer\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1811
#    1812         except BaseException as e:
# -> 1813             self._handle_dbapi_exception(
#    1814                 e, statement, parameters, cursor, context
#    1815             )
#
# ~\.conda\envs\summer\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1992                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1993             elif should_wrap:
# -> 1994                 util.raise_(
#    1995                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1996                 )
#
# ~\.conda\envs\summer\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~\.conda\envs\summer\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1768                             break
#    1769                 if not evt_handled:
# -> 1770                     self.dialect.do_execute(
#    1771                         cursor, statement, parameters, context
#    1772                     )
#
# ~\.conda\envs\summer\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     715
#     716     def do_execute(self, cursor, statement, parameters, context=None):
# --> 717         cursor.execute(statement, parameters)
#     718
#     719     def do_execute_no_params(self, cursor, statement, context=None):
#
# ProgrammingError: (pyodbc.ProgrammingError) ('The SQL contains 0 parameter markers, but 28 parameters were supplied', 'HY000')
# [SQL: INSERT INTO current_weather
#
#                                 (    position_long
#                                     ,position_lat
#                                     ,weather_id
#                                     ,main
#                                     ,description
#                                     ,icon
#                                     ,icon_url
#                                     ,base
#                                     ,temp
#                                     ,feels_like
#                                     ,temp_min
#                                     ,temp_max
#                                     ,pressure
#                                     ,humidity
#                                     ,visibility
#                                     ,wind_speed
#                                     ,wind_degree
#                                     ,clouds_all
#                                     ,datetime
#                                     ,sys_type
#                                     ,sys_id
#                                     ,sys_country
#                                     ,sys_sunrise
#                                     ,sys_sunset
#                                     ,timezone
#                                     ,id
#                                     ,name
#                                     ,cod)
#
#                             VALUES
#                                 (%s
#                                   ,%s
#                                   ,%s
#
#                                   ,%s
#                                   ,%s
#                                   ,%s
#                                   ,%s
#                                   ,%s
#
#                                   ,%s
#                                   ,%s
#                                   ,%s
#                                   ,%s
#                                   ,%s
#                                   ,%s
#                                   ,%s
#                                   ,%s
#
#                                   ,%s
#                                   ,%s
#
#                                   ,%s
#
#                                   ,%s
#                                   ,%s
#                                   ,%s
#                                   ,%s
#
#                                   ,%s
#                                   ,%s
#
#                                   ,%s
#                                   ,%s
#                                   ,%s
#                                   ,%s
#                                   ,%s)
#                                     ]
# [parameters: ('-6.26031', '53.349805', 802, 'Clouds', 'scattered clouds', '03d', 'http://openweathermap.org/img/wn/03d@2x.png', 'stations', 286.06, 285.16, 285.68, 286.86, 1019, 67, 10000, 3.13, 26, 40, 1624009006, 2, 2036125, 'IE', 1623988579, 1624049765, 3600, 2962486, 'Mountjoy', 200)]
# (Background on this error at: http://sqlalche.me/e/14/f405)

# %%
test = """
SELECT current_weather
FROM the_departed.current_weather
"""

# %%
engine.execute(test)

# %%
# Get an API response for the same co-ordinates as our historic weather data
DublinWeather = get_weather('53.349805', '-6.26031')
pprint(DublinWeather)
